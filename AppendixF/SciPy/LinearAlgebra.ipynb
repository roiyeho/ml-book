# %%
import numpy as np

# %%
from scipy.linalg import lu

A = np.array([[3, 2], [1, 4]])
P, L, U = lu(A)

print("P =\n", P)
print("L =\n", L)
print("U =\n", U)
# Out:
# P =
#  [[1. 0.]
#  [0. 1.]]
# L =
#  [[1.         0.        ]
#  [0.33333333 1.        ]]
# U =
#  [[3.         2.        ]
#  [0.         3.33333333]]
