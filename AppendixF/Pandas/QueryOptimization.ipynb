# %%
import pandas as pd

# %%
df = pd.read_csv('data/flights_sample_3m.csv')

# %%
df[(df['ORIGIN'] == 'JFK') & (df['DEP_DELAY'] > 60)]
# Out:
#             FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 726      2019-08-17         JetBlue Airways         JetBlue Airways: B6
# 1592     2023-08-25         JetBlue Airways         JetBlue Airways: B6
# 1714     2019-11-08         JetBlue Airways         JetBlue Airways: B6
# 3475     2023-04-18         JetBlue Airways         JetBlue Airways: B6
# 4118     2020-02-09  American Airlines Inc.  American Airlines Inc.: AA
# ...             ...                     ...                         ...
# 2998402  2023-08-23         JetBlue Airways         JetBlue Airways: B6
# 2998634  2019-07-07   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO
# 2999015  2022-07-25         JetBlue Airways         JetBlue Airways: B6
# 2999314  2022-06-22         JetBlue Airways         JetBlue Airways: B6
# 2999678  2023-08-17    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
#
#         AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN   ORIGIN_CITY DEST  \
# ...

# %%
df.query("ORIGIN == 'JFK' and DEP_DELAY > 60")
# Out:
#             FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 726      2019-08-17         JetBlue Airways         JetBlue Airways: B6
# 1592     2023-08-25         JetBlue Airways         JetBlue Airways: B6
# 1714     2019-11-08         JetBlue Airways         JetBlue Airways: B6
# 3475     2023-04-18         JetBlue Airways         JetBlue Airways: B6
# 4118     2020-02-09  American Airlines Inc.  American Airlines Inc.: AA
# ...             ...                     ...                         ...
# 2998402  2023-08-23         JetBlue Airways         JetBlue Airways: B6
# 2998634  2019-07-07   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO
# 2999015  2022-07-25         JetBlue Airways         JetBlue Airways: B6
# 2999314  2022-06-22         JetBlue Airways         JetBlue Airways: B6
# 2999678  2023-08-17    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
#
#         AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN   ORIGIN_CITY DEST  \
# ...

# %%
print('Standard Pandas:')
# %timeit df[(df['ORIGIN'] == 'JFK') & (df['DEP_DELAY'] > 60)]

print('Query method:')
# %timeit df.query("ORIGIN == 'JFK' and DEP_DELAY > 60")
# Out:
# Standard Pandas:
# 143 ms ± 3.27 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Query method:
# 79 ms ± 1.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df.eval(
    "TOTAL_DELAY_SCORE = 0.4 * DELAY_DUE_CARRIER + 0.2 * DELAY_DUE_WEATHER + "
    "0.2 * DELAY_DUE_NAS + 0.1 * DELAY_DUE_LATE_AIRCRAFT + 0.1 * DELAY_DUE_SECURITY",
    inplace=True
)

# Same as: 
df['TOTAL_DELAY_SCORE'] = (
    0.4 * df['DELAY_DUE_CARRIER'] + 0.2 * df['DELAY_DUE_WEATHER'] + 0.2 * df['DELAY_DUE_NAS'] +
    0.1 * df['DELAY_DUE_LATE_AIRCRAFT'] + 0.1 * df['DELAY_DUE_SECURITY']
)
