# %%
import pandas as pd

# %%
df = pd.read_csv('data/flights_sample_3m.csv')

# %% [markdown]
# Statistical and Aggragetion Methods

# %%
df['ARR_DELAY'].mean()
# Out:
# 4.260858150279257

# %%
df[['DEP_DELAY', 'ARR_DELAY']].median()
# Out:
# DEP_DELAY   -2.0
# ARR_DELAY   -7.0
# dtype: float64

# %%
df['AIR_TIME'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     61.0
# 0.50     95.0
# 0.75    142.0
# Name: AIR_TIME, dtype: float64

# %%
df['DISTANCE'].idxmax()
# Out:
# 751759

# %%
df['ARR_DELAY'].cumsum().head()
# Out:
# 0   -14.0
# 1   -19.0
# 2   -19.0
# 3     5.0
# 4     4.0
# Name: ARR_DELAY, dtype: float64

# %%
(df['DEP_DELAY'] > 60).any()
# Out:
# True

# %%
(df['DEP_DELAY'] > 60).sum()
# Out:
# 178136

# %% [markdown]
# Correlation Analysis

# %%
print(df[['DEP_DELAY', 'TAXI_OUT', 'AIR_TIME', 'ARR_DELAY']].cov())
# Out:
#              DEP_DELAY   TAXI_OUT     AIR_TIME    ARR_DELAY
# DEP_DELAY  2425.743239  23.905564    71.603150  2421.775393
# TAXI_OUT     23.905564  84.509433    36.536795    91.576208
# AIR_TIME     71.603150  36.536795  4865.738191    61.241289
# ARR_DELAY  2421.775393  91.576208    61.241289  2618.862648

# %%
print(df[['DEP_DELAY', 'TAXI_OUT', 'AIR_TIME', 'ARR_DELAY']].corr())
# Out:
#            DEP_DELAY  TAXI_OUT  AIR_TIME  ARR_DELAY
# DEP_DELAY   1.000000   0.05287  0.020928   0.964805
# TAXI_OUT    0.052870   1.00000  0.057060   0.194940
# AIR_TIME    0.020928   0.05706  1.000000   0.017156
# ARR_DELAY   0.964805   0.19494  0.017156   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the matrix using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, fmt='.1f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.savefig('figures/correlation_matrix.pdf', bbox_inches='tight')
